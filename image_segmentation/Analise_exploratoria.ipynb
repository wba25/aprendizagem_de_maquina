# %%
import numpy as np
import scipy as sp
import pandas as pd

# %%
data_set = pd.read_csv('data/segmentation.csv')

# %%
data_set.describe()
# Out:
#        REGION-CENTROID-COL  REGION-CENTROID-ROW  REGION-PIXEL-COUNT  \
# count           213.000000           213.000000          211.000000
# mean            123.486918           121.575631            9.624013
# std              74.552603            58.928763            9.064307
# min               0.324556            -2.144507            9.000000
# 25%              60.000000            81.000000            9.000000
# 50%             123.000000           121.000000            9.000000
# 75%             189.000000           173.000000            9.000000
# max             252.000000           250.000000          140.666670
#
#        SHORT-LINE-DENSITY-5  SHORT-LINE-DENSITY-2  VEDGE-MEAN    VEDGE-SD  \
# count            211.000000            211.000000  211.000000  211.000000
# mean               0.583992             -0.137441    2.124539    5.627652
# std                8.360049              2.088885    4.279816   43.412776
# ...

# %%
data_set = data_set.dropna()
