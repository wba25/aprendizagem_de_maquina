# %%
import numpy as np
import scipy as sp
import pandas as pd

# %%
data_set = pd.read_csv('data/segmentation_data.csv')

# %%
data_set.describe()
# Out:
#        REGION-CENTROID-COL  REGION-CENTROID-ROW  REGION-PIXEL-COUNT  \
# count           213.000000           213.000000          211.000000
# mean            123.486918           121.575631            9.624013
# std              74.552603            58.928763            9.064307
# min               0.324556            -2.144507            9.000000
# 25%              60.000000            81.000000            9.000000
# 50%             123.000000           121.000000            9.000000
# 75%             189.000000           173.000000            9.000000
# max             252.000000           250.000000          140.666670
#
#        SHORT-LINE-DENSITY-5  SHORT-LINE-DENSITY-2  VEDGE-MEAN    VEDGE-SD  \
# count            211.000000            211.000000  211.000000  211.000000
# mean               0.583992             -0.137441    2.124539    5.627652
# std                8.360049              2.088885    4.279816   43.412776
# ...

# %%
data_set = data_set.dropna()

# %%
data_set.head()
# Out:
#            REGION-CENTROID-COL  REGION-CENTROID-ROW  REGION-PIXEL-COUNT  \
# BRICKFACE                140.0                125.0                 9.0
# BRICKFACE                188.0                133.0                 9.0
# BRICKFACE                105.0                139.0                 9.0
# BRICKFACE                 34.0                137.0                 9.0
# BRICKFACE                 39.0                111.0                 9.0
#
#            SHORT-LINE-DENSITY-5  SHORT-LINE-DENSITY-2  VEDGE-MEAN  VEDGE-SD  \
# BRICKFACE                   0.0                   0.0    0.277778  0.062963
# BRICKFACE                   0.0                   0.0    0.333333  0.266667
# BRICKFACE                   0.0                   0.0    0.277778  0.107407
# BRICKFACE                   0.0                   0.0    0.500000  0.166667
# BRICKFACE                   0.0                   0.0    0.722222  0.374074
#
# ...

# %%
test_set = pd.read_csv('data/segmentation_test.csv')

# %%
test_set.head()
# Out:
#        REGION-CENTROID-COL  REGION-CENTROID-ROW  REGION-PIXEL-COUNT  \
# GRASS                110.0                189.0                   9
# GRASS                 86.0                187.0                   9
# GRASS                225.0                244.0                   9
# GRASS                 47.0                232.0                   9
# GRASS                 97.0                186.0                   9
#
#        SHORT-LINE-DENSITY-5  SHORT-LINE-DENSITY-2  VEDGE-MEAN  VEDGE-SD  \
# GRASS                   0.0                   0.0    1.000000  0.666667
# GRASS                   0.0                   0.0    1.111111  0.720082
# GRASS                   0.0                   0.0    3.388889  2.195113
# GRASS                   0.0                   0.0    1.277778  1.254621
# GRASS                   0.0                   0.0    1.166667  0.691215
#
#        HEDGE-MEAN  HEDGE-SD  INTENSITY-MEAN  RAWRED-MEAN  RAWBLUE-MEAN  \
# ...

# %%
test_set = test_set.dropna()

# %%
data_set.shape
# Out:
# (207, 19)

# %%
shape_view = data_set.iloc[:,0:8].copy()

# %%
rgb_view = data_set.iloc[:,9:18].copy()

# %%
shape_view.shape
# Out:
# (207, 8)

# %%
rgb_view.shap
